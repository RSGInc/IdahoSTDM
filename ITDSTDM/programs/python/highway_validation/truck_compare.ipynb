# %%
import pandas as pd

trucks_2010 = pd.read_csv(r'C:\projects\IdahoSTDM\ITD_STDM\IdahoSTDM\ITDSTDM\outputs_2010\exported_truck_trips.csv')
trucks_2020 = pd.read_csv(r'C:\projects\IdahoSTDM\ITD_STDM\IdahoSTDM\ITDSTDM\outputs_2020\exported_truck_trips.csv')

# %%
pd.DataFrame({'trucks_2010': trucks_2010.sum(), 'trucks_2020': trucks_2020.sum()}).style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7abe7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7abe7_level0_col0" class="col_heading level0 col0" >trucks_2010</th>
#       <th id="T_7abe7_level0_col1" class="col_heading level0 col1" >trucks_2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7abe7_level0_row0" class="row_heading level0 row0" >origin</th>
#       <td id="T_7abe7_row0_col0" class="data row0 col0" >79,635,600</td>
#       <td id="T_7abe7_row0_col1" class="data row0 col1" >37,887,700</td>
#     </tr>
#     <tr>
#       <th id="T_7abe7_level0_row1" class="row_heading level0 row1" >destination</th>
#       <td id="T_7abe7_row1_col0" class="data row1 col0" >79,299,319</td>
#       <td id="T_7abe7_row1_col1" class="data row1 col1" >37,834,073</td>
#     </tr>
#     <tr>
#       <th id="T_7abe7_level0_row2" class="row_heading level0 row2" >am_mut</th>
# ...
